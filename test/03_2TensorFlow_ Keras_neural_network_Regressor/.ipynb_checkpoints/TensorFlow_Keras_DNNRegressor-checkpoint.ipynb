# %%
#在TensorFlow 2.0中，新的Keras接口具有与 tf.estimator接口一致的功能，且其更易于学习

#1 导入相关的库和包
import os
import glob
import openpyxl
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

from sklearn import metrics

import os 
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
import tensorflow as tf
from tensorflow import keras  #用最新的版本 2.11.0 在 #7时会报错，用2.4.1就没有报错了,keras 用对应2.4.3版本
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers.experimental import preprocessing

#由于后续代码执行过程中，会有很多数据的展示与输出，其中多数数据都带有小数部分；
#为了让程序所显示的数据更为整齐、规范，我们可以对代码的浮点数、数组与NumPy对象对应的显示规则加以约束
np.set_printoptions(precision=4, suppress=True)
#precision设置小数点后显示的位数，默认为8；suppress表示是否使用定点计数法（即与科学计数法相对）

# %%
#2 参数配置
# Input parameters.
DataPath="00_Data/AllDataAll.csv"
ModelPath="02_DNNModle/"
CheckPointPath="02_DNNModle/Weights"
CheckPointName=CheckPointPath+"/Weights_{epoch:03d}_{val_loss:.4f}.hdf5"
ParameterPath="03_OtherResult/ParameterResult.xlsx"

TrainFrac=0.8
RandomSeed=np.random.randint(low=21,high=22)
CheckPointMethod='val_loss'
HiddenLayer=[64,128,256,512,512,1024,1024]
RegularizationFactor=0.0001
ActivationMethod='relu'
DropoutValue=[0.5,0.5,0.5,0.3,0.3,0.3,0.2]
OutputLayerActMethod='linear'
LossMethod='mean_absolute_error'
LearnRate=0.005
LearnDecay=0.0005
FitEpoch=500
BatchSize=9999
ValFrac=0.2
BestEpochOptMethod='adam'

# %%
#3 数据导入与数据划分
#其中，数据的每一列是一个特征，每一行是全部特征与因变量（就是下面的Petrol_Consumption）组合成的样本。
MyData = pd.read_csv(DataPath, names=['Petrol_tax','Average_income','Paved_Highways','Population_Driver_licence',
                                      'Petrol_Consumption'],header=0)

#随后，对导入的数据划分训练集与测试集
TrainData=MyData.sample(frac=TrainFrac,random_state=RandomSeed)
TestData=MyData.drop(TrainData.index)

#TrainFrac为训练集（包括验证数据）所占比例，RandomSeed为随机划分数据时所用的随机数种子

# %%
#4 联合分布图绘制
#在开始深度学习前，我们可以分别对输入数据的不同特征与因变量的关系加以查看。
#绘制联合分布图就是一种比较好的查看多个变量之间关系的方法。
#我们用seaborn来实现这一过程。seaborn是一个基于matplotlib的Python数据可视化库，
#使得我们可以通过较为简单的操作，绘制出动人的图片。代码如下
# Draw the joint distribution image.
def JointDistribution(Factors):
    plt.figure(1)
    sns.pairplot(TrainData[Factors],kind='reg',diag_kind='kde')
    sns.set(font_scale=2.0)
    DataDistribution=TrainData.describe().transpose()

# Draw the joint distribution image.
JointFactor=['Petrol_tax','Average_income','Paved_Highways','Population_Driver_licence','Petrol_Consumption']
JointDistribution(JointFactor)

#其中，JointFactor为需要绘制联合分布图的特征名称，JointDistribution函数中的kind表示联合分布图中非对角线图的类型，
#可选'reg'与'scatter'、'kde'、'hist'，'reg'代表在图片中加入一条拟合直线，'scatter'就是不加入这条直线,
#'kde'是等高线的形式，'hist'就是类似于栅格地图的形式；
#diag_kind表示联合分布图中对角线图的类型，可选'hist'与'kde'，'hist'代表直方图，'kde'代表直方图曲线化。
#font_scale是图中的字体大小。JointDistribution函数中最后一句是用来展示TrainData中每一项特征数据的统计信息，
#包括最大值、最小值、平均值、分位数等。

#图片绘制的示例如下：
#要注意，绘制联合分布图比较慢，建议大家不要选取太多的变量，否则程序会卡在这里比较长的时间。

# %%
#5 因变量分离与数据标准化
#因变量分离我们就不再多解释啦；
# Separate independent and dependent variables.
TrainX=TrainData.copy(deep=True)
TestX=TestData.copy(deep=True)
TrainY=TrainX.pop('Petrol_Consumption')
TestY=TestX.pop('Petrol_Consumption')

# %%
#5 因变量分离与数据标准化
#数据标准化
#要知道，对于机器学习、深度学习而言，数据标准化是十分重要的——
#用官网所举的一个例子：不同的特征在神经网络中会乘以相同的权重weight，
#因此输入数据的尺度（即数据不同特征之间的大小关系）将会影响到输出数据与梯度的尺度；
#因此，数据标准化可以使得模型更加稳定。

#在这里，首先说明数据标准化与归一化的区别。
#标准化即将训练集中某列的值缩放成均值为0，方差为1的状态；
#而归一化是将训练集中某列的值缩放到0和1之间。
#而在机器学习中，标准化较之归一化通常具有更高的使用频率，且标准化后的数据在神经网络训练时，其收敛将会更快。

#最后，一定要记得——标准化时只需要对训练集数据加以处理，不要把测试集Test的数据引入了！
#因为标准化只需要对训练数据加以处理，引入测试集反而会影响标准化的作用。
# Standardization data.
Normalizer=preprocessing.Normalization()
Normalizer.adapt(np.array(TrainX))

#在这里，我们直接运用preprocessing.Normalization()建立一个预处理层，
#其具有数据标准化的功能；随后，通过.adapt()函数将需要标准化的数据（即训练集的自变量）放入这一层，
#便可以实现数据的标准化操作。

# %%
#6 原有模型删除
# Delete the model result from the last run.
def DeleteOldModel(ModelPath):
    AllFileName=os.listdir(ModelPath) # 获取ModelPath路径下全部文件与文件夹
    for i in AllFileName:
        NewPath=os.path.join(ModelPath,i) # 分别将所获取的文件或文件夹名称与ModelPath路径组合
        if os.path.isdir(NewPath): # 若组合后的新路径是一个文件夹
            DeleteOldModel(NewPath) # 递归调用DeleteOldModel函数
        else:
            #os.chmod(NewPath,0o755)
            os.remove(NewPath) # 若不是一个新的文件夹，而是一个文件，那么就删除
            os.system('del '+NewPath)
            
# Delete the model result from the last run.
DeleteOldModel(ModelPath)

# %%
#7 最优Epoch保存与读取
#在我们训练模型的过程中，会让模型运行几百个Epoch（一个Epoch即全部训练集数据样本均进入模型训练一次）；
#而由于每一次的Epoch所得到的精度都不一样，那么我们自然需要挑出几百个Epoch中最优秀的那一个Epoch。

# Find and save optimal epoch.
def CheckPoint(Name):
    Checkpoint=ModelCheckpoint(Name,
                               monitor=CheckPointMethod,
                               verbose=1,
                               save_best_only=True,
                               mode='auto')
    CallBackList=[Checkpoint]
    return CallBackList

# Find and save optimal epochs.
CallBack=CheckPoint(CheckPointName)

#其中，Name就是保存Epoch的路径与文件名命名方法；
#monitor是我们挑选最优Epoch的依据，在这里我们用验证集数据对应的误差来判断这个Epoch是不是我们想要的；
#verbose用来设置输出日志的内容，我们用1就好；
#save_best_only用来确定我们是否只保存被认定为最优的Epoch；
#mode用以判断我们的monitor是越大越好还是越小越好，前面提到了我们的monitor是验证集数据对应的误差，
#那么肯定是误差越小越好，所以这里可以用'auto'或'min'，
#其中'auto'是模型自己根据用户选择的monitor方法来判断越大越好还是越小越好。

#找到最优Epoch后，将其传递给CallBack。需要注意的是，
#这里的最优Epoch是多个Epoch——因为每一次Epoch只要获得了当前模型所遇到的最优解，它就会保存；
#下一次再遇见一个更好的解时，同样保存，且不覆盖上一次的Epoch。
#可以这么理解，假如一共有三次Epoch，所得到的误差分别为5，7，4；那么我们保存的Epoch就是第一次和第三次。

# %%
#8 模型构建
#Keras接口下的模型构建就很清晰明了了。结合代码旁的注释就理解啦。
# Build DNN model.
def BuildModel(Norm):
    Model=keras.Sequential([Norm, # 数据标准化层

                            layers.Dense(HiddenLayer[0], # 指定隐藏层1的神经元个数
                                         kernel_regularizer=regularizers.l2(RegularizationFactor), # 运用L2正则化
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(), # 引入LeakyReLU这一改良的ReLU激活函数，从而加快模型收敛，减少过拟合
                            layers.BatchNormalization(), # 引入Batch Normalizing，加快网络收敛与增强网络稳固性
                            layers.Dropout(DropoutValue[0]), # 指定隐藏层1的Dropout值

                            layers.Dense(HiddenLayer[1],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[1]),

                            layers.Dense(HiddenLayer[2],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[2]),

                            layers.Dense(HiddenLayer[3],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[3]),

                            layers.Dense(HiddenLayer[4],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[4]),

                            layers.Dense(HiddenLayer[5],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[5]),

                            layers.Dense(HiddenLayer[6],
                                         kernel_regularizer=regularizers.l2(RegularizationFactor),
                                         # activation=ActivationMethod
                                         ),
                            layers.LeakyReLU(),
                            # If batch normalization is set in the last hidden layer, the error image
                            # will show a trend of first stable and then decline; otherwise, it will 
                            # decline and then stable.
                            # layers.BatchNormalization(),
                            layers.Dropout(DropoutValue[6]),

                            layers.Dense(units=1,
                                         activation=OutputLayerActMethod)]) # 最后一层就是输出层
    Model.compile(loss=LossMethod, # 指定每个批次训练误差的减小方法
                  optimizer=tf.keras.optimizers.Adam(learning_rate=LearnRate,decay=LearnDecay)) 
                  # 运用学习率下降的优化方法
    return Model

# Build DNN regression model.
DNNModel=BuildModel(Normalizer)
DNNModel.summary()
DNNHistory=DNNModel.fit(TrainX,
                        TrainY,
                        epochs=FitEpoch,
                        # batch_size=BatchSize,
                        verbose=1,
                        callbacks=CallBack,
                        validation_split=ValFrac)
#在这里，.summary()查看模型摘要，validation_split为在训练数据中，取出ValFrac所指定比例的一部分作为验证数据。
#DNNHistory则记录了模型训练过程中的各类指标变化情况，接下来我们可以基于其绘制模型训练过程的误差变化图像
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 4)                 9
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                320
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,021,834
# Trainable params: 2,016,833
# Non-trainable params: 5,001
# _________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 563.4115 - val_loss: 640.1817
#
# Epoch 00001: val_loss improved from inf to 640.18170, saving model to 02_DNNModle/Weights\Weights_001_640.1817.hdf5
# Epoch 2/500
# 1/1 [==============================] - 0s 49ms/step - loss: 560.7421 - val_loss: 639.6283
#
# Epoch 00002: val_loss improved from 640.18170 to 639.62830, saving model to 02_DNNModle/Weights\Weights_002_639.6283.hdf5
# Epoch 3/500
# 1/1 [==============================] - 0s 48ms/step - loss: 557.8665 - val_loss: 638.6848
#
# Epoch 00003: val_loss improved from 639.62830 to 638.68475, saving model to 02_DNNModle/Weights\Weights_003_638.6848.hdf5
# Epoch 4/500
# 1/1 [==============================] - 0s 54ms/step - loss: 554.8203 - val_loss: 637.4854
#
# Epoch 00004: val_loss improved from 638.68475 to 637.48541, saving model to 02_DNNModle/Weights\Weights_004_637.4854.hdf5
# Epoch 5/500
# 1/1 [==============================] - 0s 51ms/step - loss: 550.4241 - val_loss: 635.9503
#
# Epoch 00005: val_loss improved from 637.48541 to 635.95026, saving model to 02_DNNModle/Weights\Weights_005_635.9503.hdf5
# Epoch 6/500
# 1/1 [==============================] - 0s 47ms/step - loss: 544.2946 - val_loss: 633.8975
#
# Epoch 00006: val_loss improved from 635.95026 to 633.89746, saving model to 02_DNNModle/Weights\Weights_006_633.8975.hdf5
# Epoch 7/500
# 1/1 [==============================] - 0s 50ms/step - loss: 537.7425 - val_loss: 630.9056
#
# Epoch 00007: val_loss improved from 633.89746 to 630.90564, saving model to 02_DNNModle/Weights\Weights_007_630.9056.hdf5
# Epoch 8/500
# 1/1 [==============================] - 0s 49ms/step - loss: 527.3553 - val_loss: 625.5670
#
# Epoch 00008: val_loss improved from 630.90564 to 625.56702, saving model to 02_DNNModle/Weights\Weights_008_625.5670.hdf5
# Epoch 9/500
# 1/1 [==============================] - 0s 48ms/step - loss: 508.3221 - val_loss: 614.9552
#
# Epoch 00009: val_loss improved from 625.56702 to 614.95520, saving model to 02_DNNModle/Weights\Weights_009_614.9552.hdf5
# Epoch 10/500
# 1/1 [==============================] - 0s 45ms/step - loss: 485.0707 - val_loss: 594.1942
#
# Epoch 00010: val_loss improved from 614.95520 to 594.19421, saving model to 02_DNNModle/Weights\Weights_010_594.1942.hdf5
# Epoch 11/500
# 1/1 [==============================] - 0s 44ms/step - loss: 444.3580 - val_loss: 550.8147
#
# Epoch 00011: val_loss improved from 594.19421 to 550.81470, saving model to 02_DNNModle/Weights\Weights_011_550.8147.hdf5
# Epoch 12/500
# 1/1 [==============================] - 0s 45ms/step - loss: 396.1493 - val_loss: 493.4513
#
# Epoch 00012: val_loss improved from 550.81470 to 493.45126, saving model to 02_DNNModle/Weights\Weights_012_493.4513.hdf5
# Epoch 13/500
# 1/1 [==============================] - 0s 45ms/step - loss: 362.2205 - val_loss: 463.2665
#
# Epoch 00013: val_loss improved from 493.45126 to 463.26651, saving model to 02_DNNModle/Weights\Weights_013_463.2665.hdf5
# Epoch 14/500
# 1/1 [==============================] - 0s 45ms/step - loss: 315.3817 - val_loss: 388.2885
#
# Epoch 00014: val_loss improved from 463.26651 to 388.28854, saving model to 02_DNNModle/Weights\Weights_014_388.2885.hdf5
# Epoch 15/500
# 1/1 [==============================] - 0s 47ms/step - loss: 259.8239 - val_loss: 348.0444
#
# Epoch 00015: val_loss improved from 388.28854 to 348.04437, saving model to 02_DNNModle/Weights\Weights_015_348.0444.hdf5
# Epoch 16/500
# 1/1 [==============================] - 0s 48ms/step - loss: 205.6560 - val_loss: 438.3102
#
# Epoch 00016: val_loss did not improve from 348.04437
# Epoch 17/500
# 1/1 [==============================] - 0s 48ms/step - loss: 183.3093 - val_loss: 512.9174
#
# Epoch 00017: val_loss did not improve from 348.04437
# Epoch 18/500
# 1/1 [==============================] - 0s 47ms/step - loss: 152.4947 - val_loss: 505.3001
#
# Epoch 00018: val_loss did not improve from 348.04437
# Epoch 19/500
# 1/1 [==============================] - 0s 45ms/step - loss: 117.4487 - val_loss: 512.5261
#
# Epoch 00019: val_loss did not improve from 348.04437
# Epoch 20/500
# 1/1 [==============================] - 0s 47ms/step - loss: 125.3172 - val_loss: 473.6613
#
# Epoch 00020: val_loss did not improve from 348.04437
# Epoch 21/500
# 1/1 [==============================] - 0s 47ms/step - loss: 115.1527 - val_loss: 388.7980
#
# Epoch 00021: val_loss did not improve from 348.04437
# Epoch 22/500
# 1/1 [==============================] - 0s 46ms/step - loss: 85.6546 - val_loss: 237.8870
#
# Epoch 00022: val_loss improved from 348.04437 to 237.88702, saving model to 02_DNNModle/Weights\Weights_022_237.8870.hdf5
# Epoch 23/500
# 1/1 [==============================] - 0s 47ms/step - loss: 112.2084 - val_loss: 250.5403
#
# Epoch 00023: val_loss did not improve from 237.88702
# Epoch 24/500
# 1/1 [==============================] - 0s 46ms/step - loss: 121.8730 - val_loss: 311.2180
#
# Epoch 00024: val_loss did not improve from 237.88702
# Epoch 25/500
# 1/1 [==============================] - 0s 48ms/step - loss: 83.3241 - val_loss: 365.8304
#
# Epoch 00025: val_loss did not improve from 237.88702
# Epoch 26/500
# 1/1 [==============================] - 0s 45ms/step - loss: 74.2310 - val_loss: 335.4069
#
# Epoch 00026: val_loss did not improve from 237.88702
# Epoch 27/500
# 1/1 [==============================] - 0s 48ms/step - loss: 74.1754 - val_loss: 253.7650
#
# Epoch 00027: val_loss did not improve from 237.88702
# Epoch 28/500
# 1/1 [==============================] - 0s 47ms/step - loss: 75.0526 - val_loss: 181.0882
#
# Epoch 00028: val_loss improved from 237.88702 to 181.08818, saving model to 02_DNNModle/Weights\Weights_028_181.0882.hdf5
#
# Epoch 00066: val_loss did not improve from 102.91523
# Epoch 67/500
# 1/1 [==============================] - 0s 47ms/step - loss: 65.9529 - val_loss: 96.0560
#
# Epoch 00067: val_loss improved from 102.91523 to 96.05599, saving model to 02_DNNModle/Weights\Weights_067_96.0560.hdf5
# Epoch 68/500
# 1/1 [==============================] - 0s 48ms/step - loss: 80.6374 - val_loss: 137.3587
#
# Epoch 00068: val_loss did not improve from 96.05599
# Epoch 69/500
# 1/1 [==============================] - 0s 46ms/step - loss: 83.3633 - val_loss: 207.0609
#
# Epoch 00069: val_loss did not improve from 96.05599
# Epoch 70/500
# 1/1 [==============================] - 0s 47ms/step - loss: 69.3630 - val_loss: 218.3652
#
# Epoch 00070: val_loss did not improve from 96.05599
# Epoch 71/500
# 1/1 [==============================] - 0s 46ms/step - loss: 60.3784 - val_loss: 182.5029
#
# Epoch 00071: val_loss did not improve from 96.05599
# Epoch 72/500
# 1/1 [==============================] - 0s 48ms/step - loss: 63.1265 - val_loss: 123.0160
#
# Epoch 00072: val_loss did not improve from 96.05599
# Epoch 73/500
# 1/1 [==============================] - 0s 47ms/step - loss: 54.8704 - val_loss: 85.7076
#
# Epoch 00073: val_loss improved from 96.05599 to 85.70761, saving model to 02_DNNModle/Weights\Weights_073_85.7076.hdf5
# Epoch 74/500
# 1/1 [==============================] - 0s 47ms/step - loss: 44.5743 - val_loss: 70.6071
#
# Epoch 00074: val_loss improved from 85.70761 to 70.60710, saving model to 02_DNNModle/Weights\Weights_074_70.6071.hdf5
# Epoch 75/500
# 1/1 [==============================] - 0s 45ms/step - loss: 64.2336 - val_loss: 88.3953
#
# Epoch 00075: val_loss did not improve from 70.60710
# Epoch 76/500
# 1/1 [==============================] - 0s 45ms/step - loss: 88.2062 - val_loss: 76.3749
#
# Epoch 00076: val_loss did not improve from 70.60710
# Epoch 77/500
# 1/1 [==============================] - 0s 47ms/step - loss: 76.7241 - val_loss: 117.0105
#
# Epoch 00077: val_loss did not improve from 70.60710
# Epoch 78/500
# 1/1 [==============================] - 0s 46ms/step - loss: 67.5851 - val_loss: 172.9861
#
# Epoch 00078: val_loss did not improve from 70.60710
# Epoch 79/500
# 1/1 [==============================] - 0s 45ms/step - loss: 42.2844 - val_loss: 214.5450
#
# Epoch 00079: val_loss did not improve from 70.60710
# Epoch 80/500
# 1/1 [==============================] - 0s 45ms/step - loss: 87.2713 - val_loss: 197.4576
#
# Epoch 00080: val_loss did not improve from 70.60710
# Epoch 81/500
# 1/1 [==============================] - 0s 45ms/step - loss: 47.4855 - val_loss: 160.9011
#
# Epoch 00081: val_loss did not improve from 70.60710
# Epoch 82/500
# 1/1 [==============================] - 0s 45ms/step - loss: 58.0146 - val_loss: 124.8503
#
# Epoch 00082: val_loss did not improve from 70.60710
# Epoch 83/500
# 1/1 [==============================] - 0s 47ms/step - loss: 55.3739 - val_loss: 123.7511
#
# Epoch 00083: val_loss did not improve from 70.60710
# Epoch 84/500
# 1/1 [==============================] - 0s 48ms/step - loss: 86.5286 - val_loss: 103.7311
#
# Epoch 00260: val_loss did not improve from 50.45419
# Epoch 261/500
# 1/1 [==============================] - 0s 44ms/step - loss: 44.5535 - val_loss: 150.4479
#
# Epoch 00261: val_loss did not improve from 50.45419
# Epoch 262/500
# 1/1 [==============================] - 0s 43ms/step - loss: 54.8948 - val_loss: 149.8338
#
# Epoch 00262: val_loss did not improve from 50.45419
# Epoch 263/500
# 1/1 [==============================] - 0s 42ms/step - loss: 42.4562 - val_loss: 145.9762
#
# Epoch 00263: val_loss did not improve from 50.45419
# Epoch 264/500
# 1/1 [==============================] - 0s 45ms/step - loss: 39.4636 - val_loss: 150.6122
#
# Epoch 00264: val_loss did not improve from 50.45419
# Epoch 265/500
# 1/1 [==============================] - 0s 44ms/step - loss: 29.4151 - val_loss: 151.9935
#
# Epoch 00265: val_loss did not improve from 50.45419
# Epoch 266/500
# 1/1 [==============================] - 0s 43ms/step - loss: 43.5419 - val_loss: 147.7479
#
# Epoch 00266: val_loss did not improve from 50.45419
# Epoch 267/500
# 1/1 [==============================] - 0s 44ms/step - loss: 45.5272 - val_loss: 148.4129
#
# Epoch 00267: val_loss did not improve from 50.45419
# Epoch 268/500
# 1/1 [==============================] - 0s 45ms/step - loss: 42.7901 - val_loss: 150.4303
#
# Epoch 00268: val_loss did not improve from 50.45419
# Epoch 269/500
# 1/1 [==============================] - 0s 44ms/step - loss: 40.3399 - val_loss: 154.7339
#
# Epoch 00269: val_loss did not improve from 50.45419
# Epoch 270/500
# 1/1 [==============================] - 0s 44ms/step - loss: 44.3906 - val_loss: 160.4144
#
# Epoch 00270: val_loss did not improve from 50.45419
# ...
#
# Epoch 00398: val_loss did not improve from 50.45419
# Epoch 399/500
# 1/1 [==============================] - 0s 44ms/step - loss: 39.8208 - val_loss: 142.6738
#
# Epoch 00399: val_loss did not improve from 50.45419
# Epoch 400/500
# 1/1 [==============================] - 0s 42ms/step - loss: 44.0158 - val_loss: 120.2369
#
# Epoch 00400: val_loss did not improve from 50.45419
# Epoch 401/500
# 1/1 [==============================] - 0s 42ms/step - loss: 39.2778 - val_loss: 112.9979
#
# Epoch 00401: val_loss did not improve from 50.45419
# Epoch 402/500
# 1/1 [==============================] - 0s 43ms/step - loss: 63.6447 - val_loss: 114.3100
#
# Epoch 00402: val_loss did not improve from 50.45419
# Epoch 403/500
# 1/1 [==============================] - 0s 42ms/step - loss: 34.7417 - val_loss: 111.4558
#
# Epoch 00403: val_loss did not improve from 50.45419
# Epoch 404/500
# 1/1 [==============================] - 0s 43ms/step - loss: 40.7777 - val_loss: 107.8603
#
# Epoch 00404: val_loss did not improve from 50.45419
# Epoch 405/500
# 1/1 [==============================] - 0s 43ms/step - loss: 47.7674 - val_loss: 114.2792
#
# Epoch 00405: val_loss did not improve from 50.45419
# Epoch 406/500
# 1/1 [==============================] - 0s 42ms/step - loss: 39.4344 - val_loss: 132.3286
#
# Epoch 00406: val_loss did not improve from 50.45419
# Epoch 407/500
# 1/1 [==============================] - 0s 43ms/step - loss: 51.2323 - val_loss: 138.4839
#
# Epoch 00407: val_loss did not improve from 50.45419
# Epoch 408/500
# Epoch 00427: val_loss did not improve from 50.45419
# Epoch 428/500
# 1/1 [==============================] - 0s 43ms/step - loss: 42.8128 - val_loss: 118.9071
#
# Epoch 00428: val_loss did not improve from 50.45419
# Epoch 429/500
# 1/1 [==============================] - 0s 43ms/step - loss: 45.2126 - val_loss: 134.8421
#
# Epoch 00429: val_loss did not improve from 50.45419
# Epoch 430/500
# 1/1 [==============================] - 0s 43ms/step - loss: 45.9916 - val_loss: 147.5355
#
# Epoch 00430: val_loss did not improve from 50.45419
# Epoch 431/500
# 1/1 [==============================] - 0s 42ms/step - loss: 45.8746 - val_loss: 148.8302
#
# Epoch 00431: val_loss did not improve from 50.45419
# Epoch 432/500
# 1/1 [==============================] - 0s 45ms/step - loss: 42.0049 - val_loss: 141.6952
#
# Epoch 00432: val_loss did not improve from 50.45419
# Epoch 433/500
# 1/1 [==============================] - 0s 42ms/step - loss: 42.1302 - val_loss: 128.5309
#
# Epoch 00433: val_loss did not improve from 50.45419
# Epoch 434/500
# 1/1 [==============================] - 0s 42ms/step - loss: 42.2311 - val_loss: 119.3829
#
# Epoch 00434: val_loss did not improve from 50.45419
# Epoch 435/500
# 1/1 [==============================] - 0s 42ms/step - loss: 54.9468 - val_loss: 115.1502
#
# Epoch 00435: val_loss did not improve from 50.45419
# Epoch 436/500
# 1/1 [==============================] - 0s 42ms/step - loss: 38.6253 - val_loss: 107.6706
#
# Epoch 00436: val_loss did not improve from 50.45419
# Epoch 437/500
# 1/1 [==============================] - 0s 43ms/step - loss: 44.6412 - val_loss: 112.0101
#
# Epoch 00437: val_loss did not improve from 50.45419
# Epoch 438/500
# 1/1 [==============================] - 0s 42ms/step - loss: 39.1607 - val_loss: 113.6537
#
# Epoch 00438: val_loss did not improve from 50.45419
# Epoch 439/500
# 1/1 [==============================] - 0s 43ms/step - loss: 36.0910 - val_loss: 121.6748
#
# Epoch 00439: val_loss did not improve from 50.45419
# Epoch 440/500
# 1/1 [==============================] - 0s 42ms/step - loss: 36.8927 - val_loss: 127.3143
#
# Epoch 00440: val_loss did not improve from 50.45419
# Epoch 441/500
# 1/1 [==============================] - 0s 41ms/step - loss: 31.2566 - val_loss: 133.7475
#
# Epoch 00441: val_loss did not improve from 50.45419
# Epoch 442/500
# 1/1 [==============================] - 0s 42ms/step - loss: 36.0013 - val_loss: 131.9322
#
# Epoch 00442: val_loss did not improve from 50.45419
# Epoch 443/500
# 1/1 [==============================] - 0s 43ms/step - loss: 38.5713 - val_loss: 128.2874
#
# Epoch 00443: val_loss did not improve from 50.45419
# Epoch 444/500
# 1/1 [==============================] - 0s 42ms/step - loss: 38.5623 - val_loss: 132.2273
#
# Epoch 00444: val_loss did not improve from 50.45419
# Epoch 445/500
# 1/1 [==============================] - 0s 43ms/step - loss: 37.5347 - val_loss: 131.9857
#
# Epoch 00445: val_loss did not improve from 50.45419
# Epoch 446/500
# 1/1 [==============================] - 0s 43ms/step - loss: 39.1973 - val_loss: 129.2256
#
# Epoch 00446: val_loss did not improve from 50.45419
# Epoch 447/500
# 1/1 [==============================] - 0s 42ms/step - loss: 29.7887 - val_loss: 124.4425
#
# Epoch 00447: val_loss did not improve from 50.45419
# Epoch 448/500
# 1/1 [==============================] - 0s 42ms/step - loss: 40.5311 - val_loss: 114.3108
#
# Epoch 00448: val_loss did not improve from 50.45419
# Epoch 449/500
# 1/1 [==============================] - 0s 42ms/step - loss: 43.3103 - val_loss: 112.8698
#
# Epoch 00449: val_loss did not improve from 50.45419
# Epoch 450/500
# 1/1 [==============================] - 0s 43ms/step - loss: 41.6182 - val_loss: 114.5196
#
# Epoch 00450: val_loss did not improve from 50.45419
# Epoch 451/500
# 1/1 [==============================] - 0s 42ms/step - loss: 39.8979 - val_loss: 121.5528
#
# Epoch 00451: val_loss did not improve from 50.45419
# Epoch 452/500
# 1/1 [==============================] - 0s 42ms/step - loss: 39.4903 - val_loss: 135.0883
#
# Epoch 00452: val_loss did not improve from 50.45419
# Epoch 453/500
# 1/1 [==============================] - 0s 42ms/step - loss: 30.8234 - val_loss: 142.4682
#
# Epoch 00453: val_loss did not improve from 50.45419
# Epoch 454/500
# 1/1 [==============================] - 0s 44ms/step - loss: 46.8866 - val_loss: 140.5244
#
# Epoch 00454: val_loss did not improve from 50.45419
# Epoch 455/500
# 1/1 [==============================] - 0s 43ms/step - loss: 41.3413 - val_loss: 139.9409
#
# Epoch 00455: val_loss did not improve from 50.45419
# Epoch 456/500
# 1/1 [==============================] - 0s 43ms/step - loss: 41.7732 - val_loss: 136.9921
#
# Epoch 00456: val_loss did not improve from 50.45419
# Epoch 457/500
# 1/1 [==============================] - 0s 44ms/step - loss: 41.9109 - val_loss: 132.7263
#
# Epoch 00457: val_loss did not improve from 50.45419
# Epoch 458/500
# 1/1 [==============================] - 0s 44ms/step - loss: 33.8073 - val_loss: 117.3120
#
# Epoch 00458: val_loss did not improve from 50.45419
# Epoch 459/500
# 1/1 [==============================] - 0s 43ms/step - loss: 36.6701 - val_loss: 110.1046
#
# Epoch 00459: val_loss did not improve from 50.45419
# Epoch 460/500
# 1/1 [==============================] - 0s 43ms/step - loss: 37.5008 - val_loss: 108.1130
#
# Epoch 00460: val_loss did not improve from 50.45419
# Epoch 461/500
# 1/1 [==============================] - 0s 42ms/step - loss: 40.0037 - val_loss: 106.2336
#
# Epoch 00461: val_loss did not improve from 50.45419
# Epoch 462/500
# 1/1 [==============================] - 0s 42ms/step - loss: 42.5320 - val_loss: 107.0431
#
# Epoch 00462: val_loss did not improve from 50.45419
# Epoch 463/500
# 1/1 [==============================] - 0s 42ms/step - loss: 44.6965 - val_loss: 118.0225
#
# Epoch 00463: val_loss did not improve from 50.45419
# Epoch 464/500
# 1/1 [==============================] - 0s 42ms/step - loss: 37.7882 - val_loss: 136.0392
#
# Epoch 00464: val_loss did not improve from 50.45419
# Epoch 465/500
# 1/1 [==============================] - 0s 42ms/step - loss: 56.6335 - val_loss: 144.5234
#
# Epoch 00465: val_loss did not improve from 50.45419
# Epoch 466/500
# 1/1 [==============================] - 0s 43ms/step - loss: 53.9186 - val_loss: 142.0426
#
# Epoch 00466: val_loss did not improve from 50.45419
# Epoch 467/500
# 1/1 [==============================] - 0s 43ms/step - loss: 40.9142 - val_loss: 138.3809
#
# Epoch 00467: val_loss did not improve from 50.45419
# Epoch 468/500
# 1/1 [==============================] - 0s 43ms/step - loss: 41.1961 - val_loss: 129.7979
#
# Epoch 00468: val_loss did not improve from 50.45419
# Epoch 469/500
# 1/1 [==============================] - 0s 43ms/step - loss: 48.1909 - val_loss: 121.4721
#
# Epoch 00469: val_loss did not improve from 50.45419
# Epoch 470/500
# 1/1 [==============================] - 0s 42ms/step - loss: 62.0105 - val_loss: 116.3841
#
# Epoch 00470: val_loss did not improve from 50.45419
# Epoch 471/500
# 1/1 [==============================] - 0s 43ms/step - loss: 39.9334 - val_loss: 116.0358
#
# Epoch 00471: val_loss did not improve from 50.45419
# Epoch 472/500
# 1/1 [==============================] - 0s 42ms/step - loss: 48.4855 - val_loss: 106.3760
#
# Epoch 00472: val_loss did not improve from 50.45419
# Epoch 473/500
# 1/1 [==============================] - 0s 44ms/step - loss: 33.3958 - val_loss: 101.5186
#
# Epoch 00473: val_loss did not improve from 50.45419
# Epoch 474/500
# 1/1 [==============================] - 0s 43ms/step - loss: 58.7119 - val_loss: 105.4789
#
# Epoch 00474: val_loss did not improve from 50.45419
# Epoch 475/500
# 1/1 [==============================] - 0s 44ms/step - loss: 59.6597 - val_loss: 117.1247
#
# Epoch 00475: val_loss did not improve from 50.45419
# Epoch 476/500
# 1/1 [==============================] - 0s 43ms/step - loss: 54.1272 - val_loss: 113.9986
#
# Epoch 00476: val_loss did not improve from 50.45419
# Epoch 477/500
# 1/1 [==============================] - 0s 43ms/step - loss: 47.3407 - val_loss: 114.0368
#
# Epoch 00477: val_loss did not improve from 50.45419
# Epoch 478/500
# 1/1 [==============================] - 0s 42ms/step - loss: 34.1275 - val_loss: 111.3101
#
# Epoch 00478: val_loss did not improve from 50.45419
# Epoch 479/500
# 1/1 [==============================] - 0s 43ms/step - loss: 32.5308 - val_loss: 106.8081
#
# Epoch 00479: val_loss did not improve from 50.45419
# Epoch 480/500
# 1/1 [==============================] - 0s 43ms/step - loss: 56.1867 - val_loss: 106.0612
#
# Epoch 00480: val_loss did not improve from 50.45419
# Epoch 481/500
# 1/1 [==============================] - 0s 43ms/step - loss: 43.6234 - val_loss: 112.5272
#
# Epoch 00481: val_loss did not improve from 50.45419
# Epoch 482/500
# 1/1 [==============================] - 0s 44ms/step - loss: 35.1035 - val_loss: 119.3664
#
# Epoch 00482: val_loss did not improve from 50.45419
# Epoch 483/500
# 1/1 [==============================] - 0s 43ms/step - loss: 34.2482 - val_loss: 131.8845
#
# Epoch 00483: val_loss did not improve from 50.45419
# Epoch 484/500
# 1/1 [==============================] - 0s 43ms/step - loss: 40.0127 - val_loss: 142.2617
#
# Epoch 00484: val_loss did not improve from 50.45419
# Epoch 485/500
# 1/1 [==============================] - 0s 43ms/step - loss: 45.0716 - val_loss: 142.7353
#
# Epoch 00485: val_loss did not improve from 50.45419
# Epoch 486/500
# 1/1 [==============================] - 0s 43ms/step - loss: 50.9517 - val_loss: 134.1054
#
# Epoch 00486: val_loss did not improve from 50.45419
# Epoch 487/500
# 1/1 [==============================] - 0s 46ms/step - loss: 47.7352 - val_loss: 124.5922
#
# Epoch 00487: val_loss did not improve from 50.45419
# Epoch 488/500
# 1/1 [==============================] - 0s 44ms/step - loss: 39.4377 - val_loss: 117.8506
# Epoch 00488: val_loss did not improve from 50.45419
# Epoch 489/500
# 1/1 [==============================] - 0s 43ms/step - loss: 38.4175 - val_loss: 116.9522
#
# Epoch 00489: val_loss did not improve from 50.45419
# Epoch 490/500
# 1/1 [==============================] - 0s 43ms/step - loss: 37.7402 - val_loss: 119.7230
#
# Epoch 00490: val_loss did not improve from 50.45419
# Epoch 491/500
# 1/1 [==============================] - 0s 42ms/step - loss: 43.3824 - val_loss: 132.7884
#
# Epoch 00491: val_loss did not improve from 50.45419
# Epoch 492/500
# 1/1 [==============================] - 0s 44ms/step - loss: 38.3945 - val_loss: 148.4040
#
# Epoch 00492: val_loss did not improve from 50.45419
# Epoch 493/500
# 1/1 [==============================] - 0s 43ms/step - loss: 51.3400 - val_loss: 156.5667
#
# Epoch 00493: val_loss did not improve from 50.45419
# Epoch 494/500
# 1/1 [==============================] - 0s 43ms/step - loss: 52.1576 - val_loss: 152.3953
#
# Epoch 00494: val_loss did not improve from 50.45419
# Epoch 495/500
# 1/1 [==============================] - 0s 43ms/step - loss: 34.6380 - val_loss: 141.9460
#
# Epoch 00495: val_loss did not improve from 50.45419
# Epoch 496/500
# 1/1 [==============================] - 0s 43ms/step - loss: 40.9236 - val_loss: 125.3061
#
# Epoch 00496: val_loss did not improve from 50.45419
# Epoch 497/500
# 1/1 [==============================] - 0s 43ms/step - loss: 39.8863 - val_loss: 108.4148
#
# Epoch 00497: val_loss did not improve from 50.45419
# Epoch 498/500
# 1/1 [==============================] - 0s 43ms/step - loss: 50.1182 - val_loss: 98.9098
#
# Epoch 00498: val_loss did not improve from 50.45419
# Epoch 499/500
# 1/1 [==============================] - 0s 43ms/step - loss: 43.1557 - val_loss: 101.0327
#
# Epoch 00499: val_loss did not improve from 50.45419
# Epoch 500/500
# 1/1 [==============================] - 0s 43ms/step - loss: 53.9487 - val_loss: 103.4347
#
# Epoch 00500: val_loss did not improve from 50.45419

# %%
#9 训练图像绘制
#机器学习中，过拟合是影响训练精度的重要因素。
#因此，我们最好在训练模型的过程中绘制训练数据、验证数据的误差变化图像，从而更好获取模型的训练情况。
# Draw error image.
def LossPlot(History):
    plt.figure(2)
    plt.plot(History.history['loss'],label='loss')
    plt.plot(History.history['val_loss'],label='val_loss')
    plt.ylim([0,4000])
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)

# Draw error image.
LossPlot(DNNHistory)

#其中，'loss'与'val_loss'分别是模型训练过程中，训练集、验证集对应的误差；
#如果训练集误差明显小于验证集误差，就说明模型出现了过拟合。

# %%
#10 最优Epoch选取
#前面提到了，我们将多个符合要求的Epoch保存在了指定的路径下，
#那么最终我们可以从中选取最好的那个Epoch，作为模型的最终参数，从而对测试集数据加以预测。
#那么在这里，我们需要将这一全局最优Epoch选取出，并带入到最终的模型里。
# Optimize the model based on optimal epoch.
def BestEpochIntoModel(Path,Model):
    EpochFile=glob.glob(Path+'/*')
    BestEpoch=max(EpochFile,key=os.path.getmtime)
    Model.load_weights(BestEpoch)
    Model.compile(loss=LossMethod,
                  optimizer=BestEpochOptMethod)
    return Model

# Optimize the model based on optimal epoch.
DNNModel=BestEpochIntoModel(CheckPointPath,DNNModel)
                            
#总的来说，这里就是运用了os.path.getmtime模块，
#将我们存储Epoch的文件夹中最新的那个Epoch挑出来——这一Epoch就是使得验证集数据误差最小的全局最优Epoch；
#并通过load_weights将这一Epoch对应的模型参数引入模型。

# %%
#11 模型测试、拟合图像绘制、精度验证与模型参数与结果保存

# Draw Test image.
def TestPlot(TestY,TestPrediction):
    plt.figure(3)
    ax=plt.axes(aspect='equal')
    plt.scatter(TestY,TestPrediction)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    Lims=[0,10000]
    plt.xlim(Lims)
    plt.ylim(Lims)
    plt.plot(Lims,Lims)
    plt.grid(False)

# Verify the accuracy and draw error hist image.
def AccuracyVerification(TestY,TestPrediction):
    DNNError=TestPrediction-TestY
    plt.figure(4)
    plt.hist(DNNError,bins=30)
    plt.xlabel('Prediction Error')
    plt.ylabel('Count')
    plt.grid(False)
    Pearsonr=stats.pearsonr(TestY,TestPrediction)
    R2=metrics.r2_score(TestY,TestPrediction)
    RMSE=metrics.mean_squared_error(TestY,TestPrediction)**0.5
    print('Pearson correlation coefficient is {0}, and RMSE is {1}.'.format(Pearsonr[0],RMSE))
    return (Pearsonr[0],R2,RMSE)

# Save key parameters.
def WriteAccuracy(*WriteVar):
    ExcelData=openpyxl.load_workbook(WriteVar[0])
    SheetName=ExcelData.get_sheet_names()
    WriteSheet=ExcelData.get_sheet_by_name(SheetName[0])
    WriteSheet=ExcelData.active
    MaxRowNum=WriteSheet.max_row
    for i in range(len(WriteVar)-1):
        exec("WriteSheet.cell(MaxRowNum+1,i+1).value=WriteVar[i+1]")
    ExcelData.save(WriteVar[0])

# Predict test set data.
TestPrediction=DNNModel.predict(TestX).flatten()

# Draw Test image.
TestPlot(TestY,TestPrediction)

# Verify the accuracy and draw error hist image.
AccuracyResult=AccuracyVerification(TestY,TestPrediction)
PearsonR,R2,RMSE=AccuracyResult[0],AccuracyResult[1],AccuracyResult[2]

# Save model and key parameters.
DNNModel.save(ModelPath)
WriteAccuracy(ParameterPath,PearsonR,R2,RMSE,TrainFrac,RandomSeed,CheckPointMethod,
              ','.join('%s' %i for i in HiddenLayer),RegularizationFactor,
              ActivationMethod,','.join('%s' %i for i in DropoutValue),OutputLayerActMethod,
              LossMethod,LearnRate,LearnDecay,FitEpoch,BatchSize,ValFrac,BestEpochOptMethod)

#拟合图像如下：
#误差分布直方图如下：
# Out:
# Pearson correlation coefficient is 0.6796196189445843, and RMSE is 162.17401888066874.
# INFO:tensorflow:Assets written to: 02_DNNModle/assets
# D:\Miniconda\envs\cudaOCRpy37\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
# D:\Miniconda\envs\cudaOCRpy37\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
